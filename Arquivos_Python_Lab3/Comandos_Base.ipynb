# %% [markdown]
# # 17/03 — Introdução ao Git
#
# ###  Clonar repositório
# `git clone`
#
# Copia um repositório da nuvem para a sua máquina.
#
# ###  Verificar alterações
# `git status`
# Mostra o estado dos arquivos.
#
# `git diff`
# Mostra o que foi alterado nos arquivos.
#
# ### Enviar alterações para o GitHub
# `git add`
# Adiciona um arquivo específico para commit.
#
# `git commit -m "mensagem"`
# Salva as alterações com uma mensagem.
#
# `git push`
# Envia as alterações para o repositório.
#
#
#
# # 20/03 — Terminal + Git
#
# ### Comandos básicos do terminal
#
# `ls`
# Lista arquivos e pastas do diretório atual.
#
# `cd`
# Entra em uma pasta.
#
# ---
#
# ### Boas práticas com Git
#
# Adicionar arquivos específicos:
# `git add`
#
# Evitar:
# `git add .`
#
# Remover do stage:
# `git restore --staged`
#
# Desfazer alterações locais:
# `git restore`
#
# Histórico de commits:
# `git log`
#
#
# # 24/03 — UV
#
# ### O que é UV?
#
# UV é um gerenciador moderno de pacotes Python (substitui pip).
#
#
# ### Inicializar projeto
#
# `uv init`
# Cria a estrutura inicial do projeto. Usar uma vez.
#
#
#
# ### Sincronizar dependências
#
# `uv sync`
# Instala todas as dependências do projeto.
#
#
# ### Instalar pacotes
#
# `uv add`
#
# Exemplo:
# uv add jupyter pandas numpy
#
#
# ### Rodar comandos no ambiente
#
# `uv run`
#
# Exemplo:
# uv run jupyter notebook
#
# Se aparecer erro "program not found", significa que o pacote não foi instalado.
#
# ### Jupyter
#
# `uv add pandas`
# `uv run jupyter notebook`
#
#
# ## Manipulação de arquivos no terminal
#
# `cat`
# Printa no terminal um arquivo.
#
# ## Ignorar arquivos no Git
#
# Criar arquivo:
# `touch .gitignore`
# Alterar o txt na pasta pessoal.
#
# Exemplo:
# `.venv/
# .Rhistory
# .env`
#
#
# # Vi
# `ls -a`
# Verifica os arquivos ocultos na minha pasta
#
# `cd .bashrc`
# Entra no layout para adicionar codigos base toda vez que eu entrar no meu pc, como um atalho.
#
# ## Como usar o editor de texto no terminal
# `i`
# Entra no modo de editar.
#
# `o`
# Pula uma linha e já entra no modeo de editor.
#
# `Esc u`
# Desfaz a ultima alteração feita.
#
# `esc`
# Sai do modo de edição
#    - para sair sem alterações `:q!`
#    - para sair com alterações feitas `:w e deposi :q`
