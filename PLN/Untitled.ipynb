# %%
import pandas as pd

df = pd.read_csv("../PLN/data/noticias_games (2).csv")
df.head()
# Out:
#                                                  url  \
# 0  https://www.eurogamer.pt/tecmo-bowl-sera-adapt...
# 1  https://www.eurogamer.pt/fas-adoram-super-mari...
# 2  https://www.eurogamer.pt/pokemon-firered-leafg...
# 3  https://www.eurogamer.pt/switch-2-ja-alcancou-...
# 4  https://www.eurogamer.pt/produtora-de-slay-the...
#
#                                               titulo  \
# 0                Tecmo Bowl será adaptado para filme
# 1             Fãs adoram Super Mario Galaxy: O Filme
# 2  Pokémon FireRed & LeafGreen inclui conteúdo au...
# 3  Switch 2 já alcançou 58% das vendas da PS5 em ...
# 4  Produtora de Slay the Spire 2 detesta micro-tr...
#
#                                            descricao  autor  \
# 0  Tecmo Bowl, clássico da Koei Tecmo lançado no ...    NaN
# 1  Super Mario Galaxy: O Filme chegou finalmente ...    NaN
# 2  Pokémon FireRed & LeafGreen para a Nintendo Sw...    NaN
# 3  O recente relatório do governo japonês, sobre ...    NaN
# 4  Slay the Spire 2 chegou com grande sucesso, em...    NaN
#
#                                                 tags  \
# 0                                       Android, iOS
# 1  Action Adventure, Platformer, Nintendo Switch,...
# 2  Action Adventure, Pokémon FireRed and LeafGree...
# 3  Third person, Racing, Nintendo, Nintendo Switc...
# 4  Multiplayer Cooperative, Indie, PC, Slay the S...
#
#                                                texto  \
# 0  Tecmo Bowl, clássico da Koei Tecmo lançado no ...
# 1  Super Mario Galaxy: O Filme chegou finalmente ...
# 2  Pokémon FireRed & LeafGreen para a Nintendo Sw...
# 3  O recente relatório do governo japonês, sobre ...
# 4  Slay the Spire 2 chegou com grande sucesso, em...
#
#                                data
# 0  2026-02-03T16:35:31.309576+00:00
# 1  2026-04-02T07:40:11.552201+00:00
# 2  2026-03-01T09:15:15.110566+00:00
# 3  2026-02-09T13:33:14.368225+00:00
# 4  2026-03-10T14:42:15.059919+00:00

# %%
from nltk.tokenize import wordpunct_tokenize
from unidecode import unidecode


def limpar_texto(texto):
    texto = texto.lower()
    texto = unidecode(texto)
    tokens = wordpunct_tokenize(texto)
    tokens = [token for token in tokens if token.isalnum()]
    return " ".join(tokens)


df["texto_limpo"] = df["texto"].apply(limpar_texto)

df[["texto", "texto_limpo"]].head()
# Out:
#                                                texto  \
# 0  Tecmo Bowl, clássico da Koei Tecmo lançado no ...
# 1  Super Mario Galaxy: O Filme chegou finalmente ...
# 2  Pokémon FireRed & LeafGreen para a Nintendo Sw...
# 3  O recente relatório do governo japonês, sobre ...
# 4  Slay the Spire 2 chegou com grande sucesso, em...
#
#                                          texto_limpo
# 0  tecmo bowl classico da koei tecmo lancado no f...
# 1  super mario galaxy o filme chegou finalmente a...
# 2  pokemon firered leafgreen para a nintendo swit...
# 3  o recente relatorio do governo japones sobre o...
# 4  slay the spire 2 chegou com grande sucesso em ...

# %%
import nltk

from nltk.corpus import stopwords


nltk.download("stopwords", quiet=True)

stopwords_pt = stopwords.words("portuguese")
stopwords_pt = [unidecode(palavra) for palavra in stopwords_pt]
stopwords_pt = set(stopwords_pt)


def remover_stopwords(texto):
    tokens = texto.split()
    tokens = [token for token in tokens if token not in stopwords_pt]
    return tokens


df["tokens_sem_stopwords"] = df["texto_limpo"].apply(remover_stopwords)
df["texto_sem_stopwords"] = df["tokens_sem_stopwords"].str.join(" ")

df[["texto_limpo", "tokens_sem_stopwords", "texto_sem_stopwords"]].head()
# Out:
#                                          texto_limpo  \
# 0  tecmo bowl classico da koei tecmo lancado no f...
# 1  super mario galaxy o filme chegou finalmente a...
# 2  pokemon firered leafgreen para a nintendo swit...
# 3  o recente relatorio do governo japones sobre o...
# 4  slay the spire 2 chegou com grande sucesso em ...
#
#                                 tokens_sem_stopwords  \
# 0  [tecmo, bowl, classico, koei, tecmo, lancado, ...
# 1  [super, mario, galaxy, filme, chegou, finalmen...
# 2  [pokemon, firered, leafgreen, nintendo, switch...
# 3  [recente, relatorio, governo, japones, sobre, ...
# 4  [slay, the, spire, 2, chegou, grande, sucesso,...
#
#                                  texto_sem_stopwords
# 0  tecmo bowl classico koei tecmo lancado final a...
# 1  super mario galaxy filme chegou finalmente cin...
# 2  pokemon firered leafgreen nintendo switch incl...
# 3  recente relatorio governo japones sobre gastos...
# 4  slay the spire 2 chegou grande sucesso acesso ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
matriz_bow = vectorizer.fit_transform(df["texto_sem_stopwords"])

df_bow = pd.DataFrame(
    matriz_bow.toarray(),
    columns=vectorizer.get_feature_names_out()
)

df_bow.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from sklearn.feature_extraction.text import CountVectorizer
#       2 vectorizer = CountVectorizer()
#       3 matriz_bow = vectorizer.fit_transform(df["texto_sem_stopwords"])
#       4
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/sklearn/__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "cluster",
#    (...)    111     "compose",
#     112 ]
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/sklearn/base.py:20
#      18 from sklearn.exceptions import InconsistentVersionWarning
#      19 from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
# ---> 20 from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#      21 from sklearn.utils._param_validation import validate_parameter_constraints
#      22 from sklearn.utils._repr_html.base import ReprHTMLMixin, _HTMLDocumentationLinkMixin
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/sklearn/utils/__init__.py:9
#       7 from sklearn.utils import metadata_routing
#       8 from sklearn.utils._bunch import Bunch
# ----> 9 from sklearn.utils._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from sklearn.utils._indexing import _safe_indexing, resample, shuffle
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/sklearn/utils/_chunking.py:11
#       8 import numpy as np
#      10 from sklearn._config import get_config
# ---> 11 from sklearn.utils._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:14
#      11 from numbers import Integral, Real
#      13 import numpy as np
# ---> 14 from scipy.sparse import csr_matrix, issparse
#      16 from sklearn._config import config_context, get_config
#      17 from sklearn.utils.validation import _is_arraylike_not_scalar
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/scipy/sparse/__init__.py:307
#     304 import warnings as _warnings
#     305 import importlib as _importlib
# --> 307 from ._base import *
#     308 from ._csr import *
#     309 from ._csc import *
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/scipy/sparse/_base.py:8
#       5 import numpy as np
#       6 import operator
# ----> 8 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       9                        get_sum_dtype, isdense, isscalarlike, _todata,
#      10                        matrix, validateaxis, getdtype, is_pydata_spmatrix)
#      11 from scipy._lib._sparse import SparseABC, issparse
#      13 from ._matrix import spmatrix
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/scipy/sparse/_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/scipy/_lib/_util.py:17
#      14 from typing import Literal, TypeAlias, TypeVar
#      16 import numpy as np
# ---> 17 from scipy._lib._array_api import (Array, array_namespace, is_lazy_array, is_numpy,
#      18                                    is_marray, xp_size, xp_result_device, xp_result_type)
#      19 from scipy._lib._docscrape import FunctionDoc, Parameter
#      20 from scipy._lib._sparse import issparse
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/scipy/_lib/_array_api.py:24
#      21 import numpy as np
#      22 import numpy.typing as npt
# ---> 24 from scipy._lib.array_api_compat import (
#      25     is_array_api_obj,
#      26     is_lazy_array,
#      27     is_numpy_array,
#      28     is_cupy_array,
#      29     is_torch_array,
#      30     is_jax_array,
#      31     is_dask_array,
#      32     size as xp_size,
#      33     numpy as np_compat,
#      34     device as xp_device,
#      35     is_numpy_namespace as is_numpy,
#      36     is_cupy_namespace as is_cupy,
#      37     is_torch_namespace as is_torch,
#      38     is_jax_namespace as is_jax,
#      39     is_dask_namespace as is_dask,
#      40     is_array_api_strict_namespace as is_array_api_strict,
#      41 )
#      42 from scipy._lib.array_api_compat.common._helpers import _compat_module_name
#      43 from scipy._lib.array_api_extra.testing import lazy_xp_function
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/scipy/_lib/array_api_compat/numpy/__init__.py:9
#       6 # This needs to be loaded explicitly before cloning
#       7 import numpy.typing  # noqa: F401
# ----> 9 __all__ = clone_module("numpy", globals())
#      11 # These imports may overwrite names from the import * above.
#      12 from . import _aliases
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/scipy/_lib/array_api_compat/_internal.py:64, in clone_module(mod_name, globals_)
#      61 # Neither of these two methods is sufficient by itself,
#      62 # depending on various idiosyncrasies of the libraries we're wrapping.
#      63 objs = {}
# ---> 64 exec(f"from {mod.__name__} import *", objs)
#      66 for n in dir(mod):
#      67     if not n.startswith("_") and hasattr(mod, n):
#
# File <string>:1
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/numpy/testing/__init__.py:12
#      10 from . import _private, overrides
#      11 from ._private import extbuild
# ---> 12 from ._private.utils import *
#      13 from ._private.utils import _assert_valid_refcount, _gen_alignment_data
#      15 __all__ = (
#      16     _private.utils.__all__ + ['TestCase', 'overrides']
#      17 )
#
# File ~/perspectiva-dados/.venv/lib/python3.13/site-packages/numpy/testing/_private/utils.py:93
#      91 IS_PYSTON = hasattr(sys, "pyston_version_info")
#      92 HAS_REFCOUNT = getattr(sys, 'getrefcount', None) is not None and not IS_PYSTON
# ---> 93 BLAS_SUPPORTS_FPE = np._core._multiarray_umath._blas_supports_fpe(None)
#      95 HAS_LAPACK64 = numpy.linalg._umath_linalg._ilp64
#      97 IS_MUSL = False
#
# AttributeError: module 'numpy._core._multiarray_umath' has no attribute '_blas_supports_fpe'
